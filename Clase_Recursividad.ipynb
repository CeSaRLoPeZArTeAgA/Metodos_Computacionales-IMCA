# %% [markdown]
# <a href="https://colab.research.google.com/github/CeSaRLoPeZArTeAgA/Maestria-IMCA/blob/main/Clase_Recursividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MAESTRIA DE MODELIZACION MATEMATICA Y COMPUTACIONAL
# ---
# ![IMCA.jpg](data:image/jpeg;base64,...)
#
#
# ---
#
#
# # CLASE: ALGORITMO DE ITERACION VS RECURSIVIDAD

# %%
def fact_recur(n):
  if n==0:
    res=1
  else:
    res=n*fact_recur(n-1)
  return res

# %%
def fact_itera(n):
  res=1
  for i in range(1,n+1):
    res=res*i
  return res

# %%
'Ejemplo1:'
fact_itera(0)
fact_recur(0)
# Out:
# 1

# %%
'Ejemplo2: Calculo del tiempo de ejecucion entre las dos formas de calculo'

import time
import matplotlib.pyplot as plt

tiempos_iterativos=[]
for i in range(1,80):
  inicio=time.perf_counter()
  fact_itera(i)
  fin=time.perf_counter()
  tiempos_iterativos.append(fin-inicio)


tiempos_recursivos=[]
for i in range(1,80):
  inicio=time.perf_counter()
  fact_recur(i)
  fin=time.perf_counter()
  tiempos_recursivos.append(fin-inicio)

# %%
'Ploteo de los tiempos usado - Iterativo'
plt.plot(tiempos_iterativos)
plt.title('Tiempo Transcurrido por Iteracion - Metodo Iterativo',fontsize=13,color="red",style="italic")
plt.show()

# %%
'Ploteo de los tiempos usado - Recursivo'
plt.plot(tiempos_recursivos)
plt.title('Tiempo Transcurrido por Iteracion - Metodo Recursivo',fontsize=13,
          color="red",style="italic")
plt.show()

# %%
'Ploteo de los tiempos usados en Recursivo-Iterativo'
plt.plot(tiempos_iterativos,label='Iterativo')
plt.plot(tiempos_recursivos,label='Recursivo')
plt.legend()
plt.title('Tiempo Transcurrido por Iteracion - Metodo Recursivo',fontsize=13,
          color="red",style="italic")
plt.show()

# %%
def moverTorre(altura,origen, destino, intermedio):
  if altura >=1:
    moverTorre(altura-1,origen,intermedio,destino)
    print("mover disco de "+origen+" hacia "+destino)
    moverTorre(altura-1,intermedio,destino,origen)

moverTorre(3,"A","B","C")
# Out:
# mover disco de A hacia B
# mover disco de A hacia C
# mover disco de B hacia C
# mover disco de A hacia B
# mover disco de C hacia A
# mover disco de C hacia B
# mover disco de A hacia B

# %%
tiempos_hanoi=[]
for i in range(1,18):
  inicio=time.perf_counter()
  moverTorre(i,"A","B","C")
  fin=time.perf_counter()
  tiempos_hanoi.append(fin-inicio)

plt.plot(tiempos_hanoi)
plt.show()

# %%
def fibo_recur(n):
  if n==1 or n==2:
    an=1
  else:
    an=fibo_recur(n-1)+fibo_recur(n-2)
  return an

def fibo_iter(n):
  if n==1 or n==2:
    return 1

  fib_previo=1
  fib_actual=1
  for i in ranqe(1,n-1):
    fib_sig=fib_previo+fib_actual
    fib_previo,fib_actual=fib_actual,fib_sig
  return fib_actual

# %%
[fibo_recur(n) for n in range(1,7)]

tiempos_fiboRec=[]
for i in range(1,20):
  inicio=time.time()
  fibo_recur(i)
  fin=time.time()
  tiempos_fiboRec.append(fin-inicio)

plt.plot(tiempos_fiboRec)
plt.show()

# %%
tiempos_fiboIte=[]
for i in range(1,20):
  inicio=time.time()
  fibo_iter(i)
  fin=time.time()
  tiempos_fiboIte.append(fin-inicio)

plt.plot(tiempos_fiboIte)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-b750ff26dce7> in <cell line: 2>()
#       2 for i in range(1,20):
#       3   inicio=time.time()
# ----> 4   fibo_iter(i)
#       5   fin=time.time()
#       6   tiempos_fiboIte.append(fin-inicio)
#
# <ipython-input-43-9c4a2610c0d1> in fibo_iter(n)
#      12   fib_previo=1
#      13   fib_actual=1
# ---> 14   for i in ranqe(1,n-1):
#      15     fib_sig=fib_previo+fib_actual
#      16     fib_previo,fib_actual=fib_actual,fib_sig
#
# NameError: name 'ranqe' is not defined

# %%
def palin(texto,inicio,fin):
  if inicio>=fin:
    return True
  if texto[inicio]==texto[fin]:
    return palin(texto,inicio+1,fin-1)
  else:
    return False

palin("Hoog",0,3)
# Out:
# False

# %%
10//3
# Out:
# 3
